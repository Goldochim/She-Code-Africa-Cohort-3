# %% [markdown]
# # Random Password Generator

# %% [markdown]
# Summary:
# Random passwords are generated by the computer based on the length of the password inputed by the user.

# %%
#importing the random module and the string module

# %%
import random
from string import ascii_letters, digits, punctuation

# %%
#allowing the user input the desired length of string
#restricting the user from entering numbers less than 6.
#concatinating the random selected values for forming the password from letters, numbers and punctuations.

# %%
length=int(input('Enter the length of your desired password: '))

while (length<6):
    length=int(input('Your password can\'t be less than 6 digits in length. Please enter some other length: '))
if length>=6:
    print('Great choice for the length! Generating your password..........')
    password_char=string.ascii_letters+string.digits+string.punctuation
    password=[]
    for i in range(length):
        password.append(random.choice(password_char))
    password1=''.join(password)
    print('Your password is:  \n', password1)
# Out:
# Enter the length of your desired password: a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-3c0948db40f9> in <module>
# ----> 1 length=int(input('Enter the length of your desired password: '))
#       2
#       3 while (length<6):
#       4     length=int(input('Your password can\'t be less than 6 digits in length. Please enter some other length: '))
#       5 if length>=6:
#
# ValueError: invalid literal for int() with base 10: 'a'
